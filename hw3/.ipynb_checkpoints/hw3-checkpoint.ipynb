# %%
import numpy as np
from skimage import filters, morphology
import matplotlib.pyplot as plt
import random
from PIL import Image

# %%
img = Image.open('sample.jpg')
img.load()
data = np.asarray(img, dtype=np.int32)

# %% [markdown]
# ## Salt and pepper noise

# %%
sp_data = np.copy(data)
sp_data.shape
# Out:
# (480, 640, 3)

# %%
n = 4000

for _ in range(n):
    i = random.randint(0, sp_data.shape[0] - 1)
    j = random.randint(0, sp_data.shape[1] - 1)

    flag = bool(random.getrandbits(1))
    
    for _ in range(3):
        if flag:
            sp_data[i][j][_] = 255
        else:
            sp_data[i][j][_] = 0

# %%
plt.figure(figsize=(20,10))
plt.imshow(sp_data, interpolation='nearest')

# %% [markdown]
# ## Median filter (skimage)

# %%
mf_data = np.copy(np.rollaxis(data, 2))
mf_data.shape
# Out:
# (3, 480, 640)

# %%
for _ in range(mf_data.shape[0]):
    mf_data[_] = filters.median(mf_data[_], morphology.square(9))
mf_data = np.rollaxis(mf_data, 2)
mf_data = np.rollaxis(mf_data, 2)
mf_data.shape
# Out:
# /home/antonyvol/Apps/anaconda3/lib/python3.7/site-packages/skimage/util/dtype.py:126: UserWarning: Possible sign loss when converting negative image of type int32 to positive image of type uint8.
#   .format(dtypeobj_in, dtypeobj_out))
# /home/antonyvol/Apps/anaconda3/lib/python3.7/site-packages/skimage/util/dtype.py:179: UserWarning: Downcasting int32 to uint8 without scaling because max value 255 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# (480, 640, 3)

# %%
plt.figure(figsize=(20,10))
plt.imshow(mf_data, interpolation='nearest')

# %% [markdown]
# ## Box filter (skimage)

# %%
bf_data = np.copy(np.rollaxis(data, 2))
bf_data.shape
# Out:
# (3, 480, 640)

# %%
for _ in range(bf_data.shape[0]):
    bf_data[_] = filters.rank.mean(bf_data[_], morphology.square(9))
bf_data = np.rollaxis(bf_data, 2)
bf_data = np.rollaxis(bf_data, 2)
bf_data.shape
# Out:
# /home/antonyvol/Apps/anaconda3/lib/python3.7/site-packages/skimage/util/dtype.py:126: UserWarning: Possible sign loss when converting negative image of type int32 to positive image of type uint8.
#   .format(dtypeobj_in, dtypeobj_out))
# /home/antonyvol/Apps/anaconda3/lib/python3.7/site-packages/skimage/util/dtype.py:179: UserWarning: Downcasting int32 to uint8 without scaling because max value 255 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# (480, 640, 3)

# %%
plt.figure(figsize=(20,10))
plt.imshow(bf_data, interpolation='nearest')

# %% [markdown]
# ## Gaussian filter (skimage)

# %%
gf_data = np.copy(data)
gf_data.shape
# Out:
# (480, 640, 3)

# %%
gf_data = filters.gaussian(gf_data, sigma=1, multichannel=True, preserve_range=True)

# %%
plt.figure(figsize=(20,10))
plt.imshow(gf_data, interpolation='nearest')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
